# %%
#!rm -rf outputs/*

# %%
# %cd /kaggle/working

# !git clone https://github.com/mcpushka/Intelligent-Cinematic-Agent.git
# %cd /kaggle/working/Intelligent-Cinematic-Agent

# !ls
# Out:
# /kaggle/working
# Cloning into 'Intelligent-Cinematic-Agent'...
# remote: Enumerating objects: 142, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 142 (delta 85), reused 95 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (142/142), 1.87 MiB | 13.60 MiB/s, done.
# Resolving deltas: 100% (85/85), done.
# /kaggle/working/Intelligent-Cinematic-Agent
# 'panorama_tour (4).mp4'   README.md	     src
# 'panorama_tour (5).mp4'   requirements.txt   task.md

# %%
# !pip install -r requirements.txt
# !pip install gsplat plyfile
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 33.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.4 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !ls /kaggle/input     # посмотреть точное имя папки с ply
# !cp -v /kaggle/input/cinematic-agent/input-data/*.ply /kaggle/working/Intelligent-Cinematic-Agent/
# Out:
# cinematic-agent
# '/kaggle/input/cinematic-agent/input-data/ConferenceHall.ply' -> '/kaggle/working/Intelligent-Cinematic-Agent/ConferenceHall.ply'
# '/kaggle/input/cinematic-agent/input-data/Museume.ply' -> '/kaggle/working/Intelligent-Cinematic-Agent/Museume.ply'
# '/kaggle/input/cinematic-agent/input-data/outdoor-drone.ply' -> '/kaggle/working/Intelligent-Cinematic-Agent/outdoor-drone.ply'
# '/kaggle/input/cinematic-agent/input-data/outdoor-street.ply' -> '/kaggle/working/Intelligent-Cinematic-Agent/outdoor-street.ply'
# '/kaggle/input/cinematic-agent/input-data/Theater.ply' -> '/kaggle/working/Intelligent-Cinematic-Agent/Theater.ply'

# %%
# %cd /kaggle/working/Intelligent-Cinematic-Agent
# !sed -n '1,160p' src/gaussians.py
# Out:
# /kaggle/working/Intelligent-Cinematic-Agent
# import numpy as np
# import torch
# from plyfile import PlyData
#
#
# def _unpack_supersplat_data(vertex_data, chunk_data, device, max_gaussians=200000):
#     """Unpack SuperSplat packed format using chunk metadata for ranges.
#
#     Args:
#         max_gaussians: Maximum number of gaussians to load (downsample if more).
#                        Set to None to load all (may cause OOM on smaller GPUs).
#     """
#     n_gaussians = len(vertex_data)
#     n_chunks = len(chunk_data)
#
#     # Downsample if too many gaussians (to avoid GPU OOM)
#     if max_gaussians is not None and n_gaussians > max_gaussians:
#         step = n_gaussians // max_gaussians
#         indices = np.arange(0, n_gaussians, step)[:max_gaussians]
#         print(f"[INFO] Downsampling from {n_gaussians} to {len(indices)} gaussians (step={step})")
#     else:
#         indices = np.arange(n_gaussians)
#
#     # Get packed data as uint32 (with downsampling)
# ...

# %%
# %cd /kaggle/working/Intelligent-Cinematic-Agent

"""!python -m src.main \
  --scenes ConferenceHall.ply Museume.ply outdoor-drone.ply outdoor-street.ply Theater.ply \
  --output-dir outputs \
  --duration 60 \
  --fps 24 \
  --backend gsplat \
  --resolution 1280x720 \
  --device cuda"""


# !python -m src.main \
  --scenes ConferenceHall.ply \
  --output-dir outputs \
  --duration 60 \
  --fps 15 \
  --backend gsplat \
  --resolution 1280x720 \
  --device cuda
print ("end")
# Out:
# /kaggle/working/Intelligent-Cinematic-Agent
# Using device: cuda
# Target resolution: 1280x720, duration=60.0s, fps=15
#
# === Processing scene: ConferenceHall.ply ===
# ...

# %%
# !python -m src.main \
  --scenes Museume.ply outdoor-drone.ply outdoor-street.ply Theater.ply \
  --output-dir outputs \
  --duration 60 \
  --fps 15 \
  --resolution 1280x720 \
  --device cuda
# Out:
# Using device: cuda
# Target resolution: 1280x720, duration=60.0s, fps=15
#
# === Processing scene: Museume.ply ===
# [INFO] PLY elements: [PlyElement('chunk', (PlyProperty('min_x', 'float'), PlyProperty('min_y', 'float'), PlyProperty('min_z', 'float'), PlyProperty('max_x', 'float'), PlyProperty('max_y', 'float'), PlyProperty('max_z', 'float'), PlyProperty('min_scale_x', 'float'), PlyProperty('min_scale_y', 'float'), PlyProperty('min_scale_z', 'float'), PlyProperty('max_scale_x', 'float'), PlyProperty('max_scale_y', 'float'), PlyProperty('max_scale_z', 'float'), PlyProperty('min_r', 'float'), PlyProperty('min_g', 'float'), PlyProperty('min_b', 'float'), PlyProperty('max_r', 'float'), PlyProperty('max_g', 'float'), PlyProperty('max_b', 'float')), count=28867, comments=[]), PlyElement('vertex', (PlyProperty('packed_position', 'uint'), PlyProperty('packed_rotation', 'uint'), PlyProperty('packed_scale', 'uint'), PlyProperty('packed_color', 'uint')), count=7389888, comments=[])]
# ...

# %%
# %cd /kaggle/working/Intelligent-Cinematic-Agent

# !ls
# !ls outputs
# !ls outputs/ConferenceHall
# !ls -lh outputs/ConferenceHall
# Out:
# /kaggle/working/Intelligent-Cinematic-Agent
#  ConferenceHall.ply   outputs		       requirements.txt
#  Museume.ply	     'panorama_tour (4).mp4'   src
#  outdoor-drone.ply   'panorama_tour (5).mp4'   task.md
#  outdoor-street.ply   README.md		       Theater.ply
# ConferenceHall
# panorama_tour.mp4
# total 180K
# -rw-r--r-- 1 root root 180K Dec  1 20:32 panorama_tour.mp4

# %%
from IPython.display import Video

Video("outputs/ConferenceHall/panorama_tour.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
